# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("amazon_delivery.csv")

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# 2. Display the first 5 and last 5 rows of the dataset
print(df.head())  # First 5 rows
print(df.tail())  # Last 5 rows
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
# 3. Check the shape of the dataset (rows and columns)
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (43739, 16)

# %%
# 4. List the column names and data types
print("Column names and data types:\n", df.dtypes)
# Out:
# Column names and data types:
#  Order_ID            object
# Agent_Age            int64
# Agent_Rating       float64
# Store_Latitude     float64
# Store_Longitude    float64
# Drop_Latitude      float64
# Drop_Longitude     float64
# Order_Date          object
# Order_Time          object
# Pickup_Time         object
# Weather             object
# Traffic             object
# Vehicle             object
# Area                object
# Delivery_Time        int64
# Category            object
# dtype: object

# %%
# 5. Check for missing values in the dataset and count them
print("Missing values in each column:\n", df.isnull().sum())
# Out:
# Missing values in each column:
#  Order_ID            0
# Agent_Age           0
# Agent_Rating       54
# Store_Latitude      0
# Store_Longitude     0
# Drop_Latitude       0
# Drop_Longitude      0
# Order_Date          0
# Order_Time          0
# Pickup_Time         0
# Weather            91
# Traffic             0
# Vehicle             0
# Area                0
# Delivery_Time       0
# Category            0
# dtype: int64

# %%
# 6. Display summary statistics for numerical columns
print("Summary statistics:\n", df.describe())
# Out:
# Summary statistics:
#            Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# count  43739.000000  43685.000000    43739.000000     43739.000000
# mean      29.567137      4.633780       17.210960        70.661177
# std        5.815155      0.334716        7.764225        21.475005
# min       15.000000      1.000000      -30.902872       -88.366217
# 25%       25.000000      4.500000       12.933298        73.170283
# 50%       30.000000      4.700000       18.551440        75.898497
# 75%       35.000000      4.900000       22.732225        78.045359
# max       50.000000      6.000000       30.914057        88.433452
#
#        Drop_Latitude  Drop_Longitude  Delivery_Time
# count   43739.000000    43739.000000   43739.000000
# mean       17.459031       70.821842     124.905645
# std         7.342950       21.153148      51.915451
# min         0.010000        0.010000      10.000000
# 25%        12.985996       73.280000      90.000000
# ...

# %%
# 7. Identify duplicate rows and remove them
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %%
# 8. Get the number of unique values in each column
print("Unique values in each column:\n", df.nunique())
# Out:
# Unique values in each column:
#  Order_ID           43739
# Agent_Age             22
# Agent_Rating          28
# Store_Latitude       521
# Store_Longitude      415
# Drop_Latitude       4367
# Drop_Longitude      4367
# Order_Date            44
# Order_Time           177
# Pickup_Time          193
# Weather                6
# Traffic                5
# Vehicle                4
# Area                   4
# Delivery_Time         89
# Category              16
# dtype: int64

# %%
# DATA CLEANING #

# %%
df = pd.read_csv("amazon_delivery.csv")

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# Display the first few rows after dropping missing values
print(df.head())
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Length  Store_Longitude  \
# 0  ialx566343618         37           4.9     22.745049        75.892471
# 1  akqg208421122         34           4.5     12.913041        77.683237
# 2  njpu434582536         23           4.4     12.914264        77.678400
# 3  rjto796129700         38           4.7     11.003669        76.976494
# 4  zguw716275638         32           4.6     12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
# Convert 'Order_Time' to datetime format with a specified format
df["Order_Time"] = pd.to_datetime(df["Order_Time"], format="%Y-%m-%d %H:%M:%S", errors="coerce")  
# Replace "%Y-%m-%d %H:%M:%S" with the actual format of your datetime column

# %%
2# Display the first few rows to verify
print(df[["Order_Time"]].head())
# Out:
#            Order_Time
# 0 2025-03-07 11:45:00
# 1 2025-03-07 19:50:00
# 2 2025-03-07 08:45:00
# 3 2025-03-07 18:10:00
# 4 2025-03-07 13:45:00

# %%
# Display missing values before dropping rows
print("Missing values before dropping:\n", df.isnull().sum())
# Out:
# Missing values before dropping:
#  Order_ID           0
# Agent_Rating       0
# Agent_Rating       0
# Store_Length       0
# Store_Longitude    0
# Drop_Latitude      0
# Drop_Longitude     0
# Order_Date         0
# Order_Time         0
# Pickup_Time        0
# Weather            0
# Traffic            0
# Vehicle            0
# Area               0
# Delivery_Time      0
# Category           0
# dtype: int64

# %%
# Drop rows with any missing values
df.dropna(inplace=True)

# %%
# Display missing values after dropping rows
print("Missing values after dropping:\n", df.isnull().sum())
# Out:
# Missing values after dropping:
#  Order_ID           0
# Agent_Rating       0
# Agent_Rating       0
# Store_Length       0
# Store_Longitude    0
# Drop_Latitude      0
# Drop_Longitude     0
# Order_Date         0
# Order_Time         0
# Pickup_Time        0
# Weather            0
# Traffic            0
# Vehicle            0
# Area               0
# Delivery_Time      0
# Category           0
# dtype: int64

# %%
# Display the first few rows to verify
print(df.head())
# Out:
#         Order_ID  Agent_Rating  Agent_Rating  Store_Length  Store_Longitude  \
# 0  ialx566343618            37           4.9     22.745049        75.892471
# 1  akqg208421122            34           4.5     12.913041        77.683237
# 2  njpu434582536            23           4.4     12.914264        77.678400
# 3  rjto796129700            38           4.7     11.003669        76.976494
# 4  zguw716275638            32           4.6     12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date          Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19 2025-03-07 11:45:00    11:45:00
# 1      13.043041       77.813237  2022-03-25 2025-03-07 19:50:00    19:50:00
# 2      12.924264       77.688400  2022-03-19 2025-03-07 08:45:00    08:45:00
# 3      11.053669       77.026494  2022-04-05 2025-03-07 18:10:00    18:10:00
# 4      13.012793       80.289982  2022-03-26 2025-03-07 13:45:00    13:45:00
#
# ...

# %%
#DATA FILTERING AND SELECTION

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# 1. Select the Age column from the DataFrame
Agent_Age = df["Agent_Rating"]
print(Agent_Age.head())
# Out:
#    Agent_Rating  Agent_Rating
# 0            37           4.9
# 1            34           4.5
# 2            23           4.4
# 3            38           4.7
# 4            32           4.6

# %%
# 2. Select the Name and City columns from the DataFrame
name_city_columns = df[["Area", "Vehicle"]]
print(name_city_columns.head())
# Out:
#              Area      Vehicle
# 0          Urban   motorcycle
# 1  Metropolitian      scooter
# 2          Urban   motorcycle
# 3  Metropolitian   motorcycle
# 4  Metropolitian      scooter

# %%
# 3. Filter the DataFrame to show rows where the Weather is "cloudy"
weather_cloudy = df[df["Weather"] == "cloudy"]  # "cloudy" should be a string
print(weather_cloudy.head())
# Out:
# Empty DataFrame
# Columns: [Order_ID, Agent_Rating, Agent_Rating, Store_Length, Store_Longitude, Drop_Latitude, Drop_Longitude, Order_Date, Order_Time, Pickup_Time, Weather, Traffic, Vehicle, Area, Delivery_Time, Category]
# Index: []

# %%
# 4. Filter the dataset to display only rows where the City is "New York"
city_new_york = df[df["Category"] == "Cosmetics"]
print(city_new_york.head())
# Out:
#          Order_ID  Agent_Rating  Agent_Rating  Store_Length  Store_Longitude  \
# 3   rjto796129700            38           4.7     11.003669        76.976494
# 10  vmau710398846            21           4.7     10.003064        76.307589
# 16  vmfv999642595            33           4.2     18.592718        73.773572
# 25  edrh271340988            27           5.0     26.849596        75.800512
# 27  gzfn634029300            32           4.0     12.934179        77.615797
#
#     Drop_Latitude  Drop_Longitude  Order_Date          Order_Time Pickup_Time  \
# 3       11.053669       77.026494  2022-04-05 2025-03-07 18:10:00    18:10:00
# 10      10.043064       76.347589  2022-02-13 2025-03-07 15:05:00    15:05:00
# 16      18.702718       73.883572  2022-03-16 2025-03-07 20:40:00    20:40:00
# 25      26.879596       75.830512  2022-04-05 2025-03-07 20:40:00    20:40:00
# 27      13.024179       77.705797  2022-03-16 2025-03-07 21:35:00    21:35:00
#
# ...

# %%
#SORTING AND ORDERING

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
data_sorted_age = data.sort_values(by="Agent_Age", ascending=True)

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
df_sorted_city = df.sort_values(by="Area", ascending=True)
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
df_sorted_price = df.sort_values(by="Delivery_Time", ascending=False)

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Agent_Rating', 'Agent_Rating', 'Store_Length',
#        'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 'Order_Date',
#        'Order_Time', 'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area',
#        'Delivery_Time', 'Category'],
#       dtype='object')

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
df_top_3_age = df.sort_values(by="Order_Date", ascending=True).head(3)

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
#RENAMING COLUMNS

# %%
df.rename(columns={'Weather': 'Location'}, inplace=True)

# %%
df.rename(columns={'Agent_Age': 'Person_Age'}, inplace=True)

# %%
df.rename(columns={
    'Store_Latitude': 'Store_Lat',
    'Store_Longitude': 'Store_Lon',
    'Drop_Latitude': 'Drop_Lat',
    'Drop_Longitude': 'Drop_Lon'
}, inplace=True)

# %%
df.rename(columns={'Order_ID': 'Order'}, inplace=True)

# %%
#DATA AGGREATATION

# %%
# 3. Count how many times each value appears in the Order_Date column
order_date_counts = data["Order_Date"].value_counts()

# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_delivery.csv")
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
average_age = df["Agent_Age"].mean()
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# 3. Count how many times each value appears in the Order_Date column
order_date_counts = df["Order_Date"].value_counts()
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# 4. Calculate the total sum of Store_Latitude and Store_Longitude for each unique value in the Order_Date column
location_sums = df.groupby("Order_Date")[["Store_Latitude", "Store_Longitude"]].sum()
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# 5. Find the highest Age in the dataset
max_age = df["Agent_Age"].max()
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...
