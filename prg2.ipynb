# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("amazon_delivery.csv")

# %%
data
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 2      njpu434582536         23           4.4       12.914264
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# ...              ...        ...           ...             ...
# 43734  jlxf819993117         30           4.8       26.902328
# 43735  aevx342135787         21           4.6        0.000000
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
# Load the CSV file
data = pd.read_csv("amazon_delivery.csv")

# Check if required columns exist
if 'Store_Longitude' in data.columns and 'Drop_Latitude' in data.columns:
    # Create a simple bar plot
    plt.figure(figsize=(10, 6))
    plt.bar(data['Store_Longitude'], data['Drop_Latitude'], color='skyblue')
    plt.xlabel('Store Longitude')
    plt.ylabel('Drop Latitude')
    plt.title('Store Longitude vs Drop Latitude')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("Required columns not found in the dataset.")

# %%
    df = pd.read_csv("amazon_delivery.csv")

    # Ensure the column exists
    if 'Agent_Age' in df.columns:
        # Sum the agent_age column, handling non-numeric values
        total_age = df['Agent_Age'].dropna().astype(float).sum()
        print(f"Total sum of Agent_Age: {total_age}")
    else:
        print("Column 'Agent_Age' not found in the file.")
# Out:
# Total sum of Agent_Age: 1293237.0

# %%
df = pd.read_csv("amazon_delivery.csv")

# Check if the 'Agent_Rating' column exists
if 'Agent_Rating' in df.columns:
    # Count occurrences of each unique value
    rating_counts = df['Agent_Rating'].value_counts()
    print(rating_counts)
else:
    print("Error: 'Agent_Rating' column not found in the file.")
# Out:
# Agent_Rating
# 4.8    7148
# 4.7    7142
# 4.9    7041
# 4.6    6940
# 5.0    3996
# 4.5    3303
# 4.1    1430
# 4.2    1418
# 4.3    1409
# 4.4    1361
# 4.0    1077
# 3.5     249
# 3.8     228
# 3.7     225
# 3.6     207
# 3.9     197
# 6.0      53
# 1.0      38
# 3.4      32
# 3.1      29
# 3.2      29
# 3.3      25
# 2.6      22
# 2.7      22
# 2.5      20
# 2.8      19
# 2.9      19
# 3.0       6
# Name: count, dtype: int64

# %%
df = pd.read_csv("amazon_delivery.csv")

# Ensure relevant columns exist
if 'Agent_Age' in df.columns and 'Age' in df.columns:
    # Group by 'Agent_Age' and sum the 'Age' column
    age_sum = df.groupby('Agent_Age')['Age'].sum()
    
    # Display the result
    print(age_sum)
else:
    print("Error: Required columns 'Agent_Age' and 'Age' not found in the dataset.")
# Out:
# Error: Required columns 'Agent_Age' and 'Age' not found in the dataset.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Agent_Age', 'Agent_Rating', 'Store_Latitude',
#        'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 'Order_Date',
#        'Order_Time', 'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area',
#        'Delivery_Time', 'Category'],
#       dtype='object')

# %%
file_path = "amazon_delivery.csv"  # Update this path if necessary
df = pd.read_csv(file_path)

# Find the highest age
max_age = df["Agent_Age"].max()

print("The highest age in the dataset is:", max_age)
# Out:
# The highest age in the dataset is: 50

# %%
# Read the CSV file
try:
    df = pd.read_csv("amazon_delivery.csv")

    # Ensure the column exists
    if 'Agent_Age' in df.columns:
        # Convert to numeric in case of errors
        df['Agent_Age'] = pd.to_numeric(df['Agent_Age'], errors='coerce')

        # Drop NaN values and get the minimum age
        min_age = df['Agent_Age'].dropna().min()

        print(f"Minimum Agent Age: {min_age}")
    else:
        print("Error: 'Agent_Age' column not found in the dataset.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Minimum Agent Age: 15

# %%
                                                   #SIMPLE DATA VISUALZTION

# %%
# Count occurrences of each Weather-Traffic combination
weather_traffic_counts = df.groupby("Weather")["Traffic"].value_counts().unstack(fill_value=0)

# Plot the bar chart
weather_traffic_counts.plot(kind="bar", figsize=(10, 6))

# Customize the plot
plt.title("Weather vs. Traffic")
plt.xlabel("Weather Condition")
plt.ylabel("Count of Traffic Conditions")
plt.xticks(rotation=45)
plt.legend(title="Traffic Level")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %%
df = pd.read_csv(("amazon_delivery.csv"))

# Ensure the "Weather" column exists
if "Weather" not in df.columns:
    print("Error: 'Weather' column not found in the dataset.")
else:
    # Convert categorical weather descriptions to numerical values
    df["Weather_Encoded"] = pd.factorize(df["Weather"])[0]  # Assigns a unique number to each category

    # Plot Weather over index
    plt.figure(figsize=(10, 5))
    plt.plot(df.index, df["Weather_Encoded"], marker="o", linestyle="-", color="b", label="Weather (Encoded)")

    # Labels and title
    plt.xlabel("Index")
    plt.ylabel("Weather (Encoded)")
    plt.title("Weather Trend Over Index")
    plt.legend()
    plt.grid()

    # Show plot
    plt.show()

    # Display mapping of encoded values
    print("Weather Encoding Mapping:", dict(enumerate(pd.factorize(df["Weather"])[1])))
# Out:
# Weather Encoding Mapping: {0: 'Sunny', 1: 'Stormy', 2: 'Sandstorms', 3: 'Cloudy', 4: 'Fog', 5: 'Windy'}

# %%
df = pd.read_csv("amazon_delivery.csv")

# Check if 'Agent_Age' column exists
if 'Agent_Age' in df.columns:
    # Drop NaN values if any
    df = df.dropna(subset=['Agent_Age'])
    
    # Convert to numeric in case of string values
    df['Agent_Age'] = pd.to_numeric(df['Agent_Age'], errors='coerce')
    df = df.dropna(subset=['Agent_Age'])
    
    # Plot histogram
    plt.figure(figsize=(8, 5))
    plt.hist(df['Agent_Age'], bins=20, edgecolor='black', alpha=0.7)
    plt.xlabel('Age')
    plt.ylabel('Frequency')
    plt.title('Histogram of Agent Age')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
else:
    print("Error: 'Agent_Age' column not found in the dataset.")

# %%
df = pd.read_csv("amazon_delivery.csv")

# Ensure the "Vehicle" column exists
if "Vehicle" in df.columns:
    # Count occurrences of each vehicle type
    vehicle_counts = df["Vehicle"].value_counts()

    # Plot pie chart
    plt.figure(figsize=(8, 8))
    plt.pie(vehicle_counts, labels=vehicle_counts.index, autopct="%1.1f%%", startangle=140, colors=plt.cm.Paired.colors)
    plt.title("Distribution of Vehicles")
    plt.show()
else:
    print("Error: 'Vehicle' column not found in the dataset.")

# %%
df = pd.read_csv("amazon_delivery.csv")

# Check if required columns exist
if 'Agent_Age' in df.columns and 'Agent_Rating' in df.columns:
    # Drop rows with missing values in selected columns
    df = df.dropna(subset=['Agent_Age', 'Agent_Rating'])
    
    # Convert to numeric (if necessary)
    df['Agent_Age'] = pd.to_numeric(df['Agent_Age'], errors='coerce')
    df['Agent_Rating'] = pd.to_numeric(df['Agent_Rating'], errors='coerce')
    
    # Drop any NaN values introduced by conversion
    df = df.dropna(subset=['Agent_Age', 'Agent_Rating'])
    
    # Create scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(df['Agent_Age'], df['Agent_Rating'], alpha=0.5, c='blue', edgecolors='k')
    plt.xlabel("Agent Age")
    plt.ylabel("Agent Rating")
    plt.title("Scatter Plot: Agent Age vs. Agent Rating")
    plt.grid(True)
    plt.show()
else:
    print("Error: Required columns 'Agent_Age' and 'Agent_Rating' not found in the dataset.")

# %%
                                                        #BASIC STRING MANIPULATION

# %%
try:
    # Read the CSV file
    df = pd.read_csv("amazon_delivery.csv")

    # Check if "Weather" column exists
    if "Weather" in df.columns:
        # Extract first 3 characters from "Weather" column
        df["Weather_Extracted"] = df["Weather"].astype(str).str[:3]
        
        # Display the first few rows
        print(df[["Weather", "Weather_Extracted"]].head())

    else:
        print("Error: 'Weather' column not found in the dataset.")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#       Weather Weather_Extracted
# 0       sunny               sun
# 1      stormy               sto
# 2  sandstorms               san
# 3       sunny               sun
# 4      cloudy               clo

# %%
df = pd.read_csv("amazon_delivery.csv")

# Check if 'Weather' column exists
if 'Weather' in df.columns:
    # Convert values to lowercase
    df['Weather'] = df['Weather'].str.lower()

    # Save the updated file
    updated_file_path = "amazon_delivery.csv"
    df.to_csv(updated_file_path, index=False)
    print(f"Updated file saved at: {updated_file_path}")
else:
    print("Error: 'Weather' column not found in the CSV file.")
# Out:
# Updated file saved at: amazon_delivery.csv

# %%
df = pd.read_csv("amazon_delivery.csv")  # Update path if needed

# Create new columns for Toys and Clothing
df['Toys'] = df['Category'].apply(lambda x: 1 if x == 'Toys' else 0)
df['Clothing'] = df['Category'].apply(lambda x: 1 if x == 'Clothing' else 0)

# Save the modified DataFrame
df.to_csv("amazon_delivery_updated.csv", index=False)

# Display the first few rows to verify
print(df.head())
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Ensure "Toys" and "Clothing" columns exist
if "Toys" in df.columns and "Clothing" in df.columns:
    # Concatenate the columns with a separator (e.g., ", ")
    df["Products"] = df["Toys"].astype(str) + ", " + df["Clothing"].astype(str)

    # Save the updated DataFrame back to a new CSV file
    output_file = "/mnt/data/updated_amazon_delivery.csv"
    df.to_csv(output_file, index=False)
    print(f"Updated file saved at: {output_file}")
else:
    print(df.head())
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
def process_weather_column(file_path):
    try:
        # Read the CSV file
        df = pd.read_csv("amazon_delivery.csv")
        
        # Check if 'Weather' column exists
        if 'Weather' in df.columns:
            # Replace spaces with underscores in 'Weather' column
            df['Weather'] = df['Weather'].astype(str).str.replace(' ', '_')
            
            # Save the modified file
            output_path = file_path.replace('.csv', '_modified.csv')
            df.to_csv(output_path, index=False)
            print(f"Processed file saved as: {output_path}")
        else:
            print("Column 'Weather' not found in the CSV file.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Provide the file path
file_path = "amazon_delivery.csv"
process_weather_column(file_path)
# Out:
# Processed file saved as: amazon_delivery_modified.csv

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

# Select the first row using iloc
first_row = df.iloc[0]

# Print the first row
print(first_row)
# Out:
# Order_ID           ialx566343618
# Agent_Age                     37
# Agent_Rating                 4.9
# Store_Latitude         22.745049
# Store_Longitude        75.892471
# Drop_Latitude          22.765049
# Drop_Longitude         75.912471
# Order_Date            2022-03-19
# Order_Time              11:30:00
# Pickup_Time             11:45:00
# Weather                    sunny
# Traffic                    High
# Vehicle              motorcycle
# Area                      Urban
# Delivery_Time                120
# Category                Clothing
# Name: 0, dtype: object

# %%
                                                        # ILOC = INEGER LOCATION BASED INDEXING

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

# Select the last 3 rows using iloc
last_three_rows = df.iloc[-3:]

# Display the result
print(last_three_rows)
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 43736        80.242439      13.052394       80.272439  2022-03-11   23:50:00
# 43737        76.986241      11.041753       77.026241  2022-03-07   13:35:00
# 43738        85.325731      23.431058       85.405731  2022-03-02   17:10:00
#
#       Pickup_Time Weather  Traffic      Vehicle            Area  \
# 43736    00:05:00  cloudy     Low      scooter   Metropolitian
# 43737    13:40:00  cloudy    High   motorcycle   Metropolitian
# 43738    17:15:00     fog  Medium      scooter   Metropolitian
#
#        Delivery_Time   Category
# 43736             80       Home
# 43737            130    Kitchen
# 43738            180  Cosmetics

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

# Select the last 3 rows using iloc
last_three_rows = df.iloc[-3:]

# Display the result
print(last_three_rows)
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 43736  xnek760674819         30           4.9       13.022394
# 43737  cynl434665991         20           4.7       11.001753
# 43738  nsyz997960170         23           4.9       23.351058
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 43736        80.242439      13.052394       80.272439  2022-03-11   23:50:00
# 43737        76.986241      11.041753       77.026241  2022-03-07   13:35:00
# 43738        85.325731      23.431058       85.405731  2022-03-02   17:10:00
#
#       Pickup_Time Weather  Traffic      Vehicle            Area  \
# 43736    00:05:00  cloudy     Low      scooter   Metropolitian
# 43737    13:40:00  cloudy    High   motorcycle   Metropolitian
# 43738    17:15:00     fog  Medium      scooter   Metropolitian
#
#        Delivery_Time   Category
# 43736             80       Home
# 43737            130    Kitchen
# 43738            180  Cosmetics

# %%
df = pd.read_csv("amazon_delivery.csv")

# Select all rows but only the 2nd and 3rd columns (index 1 and 2 in zero-based indexing)
selected_columns = df.iloc[:, 1:3]

# Display the result
print(selected_columns)
# Out:
#        Agent_Age  Agent_Rating
# 0             37           4.9
# 1             34           4.5
# 2             23           4.4
# 3             38           4.7
# 4             32           4.6
# ...          ...           ...
# 43734         30           4.8
# 43735         21           4.6
# 43736         30           4.9
# 43737         20           4.7
# 43738         23           4.9
#
# [43739 rows x 2 columns]

# %%
df = pd.read_csv("amazon_delivery.csv")  # Change to read_excel if it's an Excel file

# Select the value at the 4th row (index 3) and 2nd column (index 1)
value = df.iloc[3, 1]

print("Selected Value:", value)
# Out:
# Selected Value: 38

# %%
df = pd.read_csv("amazon_delivery.csv")

# Select rows 2 to 5 and columns 1 to 4 using iloc
subset = df.iloc[2:6, 1:5]

# Display the result
print(subset)
# Out:
#    Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude
# 2         23           4.4       12.914264        77.678400
# 3         38           4.7       11.003669        76.976494
# 4         32           4.6       12.972793        80.249982
# 5         22           4.8       17.431668        78.408321

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

# 1. Select the row where the Category is "Toys" using loc
toys_row = df.loc[df["Category"] == "Toys"]
print("Rows where Category is 'Toys':\n", toys_row)
# Out:
# Rows where Category is 'Toys':
#              Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 4      zguw716275638         32           4.6       12.972793
# 5      fxuu788413734         22           4.8       17.431668
# 6      njmo150975311         33           4.7       23.369746
# 9      bgvc052754213         36           4.2       30.327968
# 19     ntzy027061451         25           4.1       18.563934
# ...              ...        ...           ...             ...
# 43636  wngr016223336         23           4.6        9.979363
# 43643  njrw746007699         30           4.6       22.310329
# 43650  ztpo366691249         22           4.7       21.183434
# 43685  lxel504664556         32           4.1       17.450851
# 43732  uftb261665932         28           4.9       13.029198
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 4            80.249982      13.012793       80.289982  2022-03-26   13:30:00
# ...

# %%
                                                         #LOC LABEL BASED INDEXING

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

age_above_30 = df.loc[df["Agent_Age"] > 30]
print("\nRows where Agent_Age > 30:\n", age_above_30)
# Out:
# Rows where Agent_Age > 30:
#              Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 0      ialx566343618         37           4.9       22.745049
# 1      akqg208421122         34           4.5       12.913041
# 3      rjto796129700         38           4.7       11.003669
# 4      zguw716275638         32           4.6       12.972793
# 6      njmo150975311         33           4.7       23.369746
# ...              ...        ...           ...             ...
# 43725  wjsq095299773         32           4.6        0.000000
# 43726  xnci921220681         34           4.9       12.297954
# 43729  llbw528617620         36           4.8       12.310972
# 43730  spgc082793916         37           4.8       13.022394
# 43733  gcxb277393192         35           4.2       23.371292
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 0            75.892471      22.765049       75.912471  2022-03-19   11:30:00
# ...

# %%
file_path = "amazon_delivery.csv"
df = pd.read_csv(file_path)

weather_filtered = df.loc[(df["Agent_Age"] >= 20) & (df["Agent_Age"] <= 40), ["Weather"]]
print("\nWeather for Agent_Age between 20 and 40:\n", weather_filtered)
# Out:
# Weather for Agent_Age between 20 and 40:
#            Weather
# 0           sunny
# 1          stormy
# 2      sandstorms
# 3           sunny
# 4          cloudy
# ...           ...
# 43734       windy
# 43735       windy
# 43736      cloudy
# 43737      cloudy
# 43738         fog
#
# [43648 rows x 1 columns]

# %%
# Load the CSV file
df = pd.read_csv("amazon_delivery.csv")

# Ensure column names are correctly read
print(df.columns)

# Select rows where 'Weather' is 'windy'
windy_df = df.loc[df['Weather'].str.lower() == 'windy']

# Display the first few rows of the filtered dataframe
print(windy_df.head())
# Out:
# Index(['Order_ID', 'Agent_Age', 'Agent_Rating', 'Store_Latitude',
#        'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 'Order_Date',
#        'Order_Time', 'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area',
#        'Delivery_Time', 'Category'],
#       dtype='object')
#          Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 15  uhfs888375680         35           4.0       12.311072        76.654878
# 18  vwmc439983136         21           4.7       22.552672        88.352885
# 22  rkzt648036688         33           4.3       12.986047        80.218114
# 27  gzfn634029300         32           4.0       12.934179        77.615797
# 28  xjps180812498         23           4.8       18.514210        73.838429
#
#     Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time Weather  \
# 15      12.351072       76.694878  2022-03-01   14:55:00    15:10:00   windy
# 18      22.582672       88.382885  2022-02-15   21:15:00    21:30:00   windy
# ...

# %%
# Define the file path
file_path = "amazon_delivery.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Selecting a specific row index (e.g., 0) and columns
row_index = 0  # Change this index to the desired row
selected_data = df.loc[row_index, ["Agent_Age", "Weather"]]

# Print the selected data
print(selected_data)
# Out:
# Agent_Age       37
# Weather      sunny
# Name: 0, dtype: object

# %%
df = pd.read_csv("amazon_delivery.csv")

# Ensure column names are correctly formatted (strip spaces, standardize case if needed)
df.columns = df.columns.str.strip()

# Apply filtering condition
filtered_df = df.loc[(df['Agent_Age'] > 25) & (df['Weather'] == 'stormy')]

# Display the filtered data
print(filtered_df)
# Out:
#             Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# 1      akqg208421122         34           4.5       12.913041
# 25     edrh271340988         27           5.0       26.849596
# 30     itii428784576         36           4.1       21.160437
# 33     zotl583816092         32           3.5        0.000000
# 39     zqtj827550147         26           4.9       12.972532
# ...              ...        ...           ...             ...
# 43709  mpbz498193455         34           4.5       30.340722
# 43713  rcjj351129276         33           4.7       22.307898
# 43721  cvez060376234         34           4.9       17.422819
# 43722  gbvc892665917         34           4.2        0.000000
# 43725  wjsq095299773         32           4.6        0.000000
#
#        Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date Order_Time  \
# 1            77.683237      13.043041       77.813237  2022-03-25   19:45:00
# ...

# %%
                                                # REPLACE : REPALCING VLAUES IN THE DATAFRAME

# %%
# Update with your actual file path
df = pd.read_csv("amazon_delivery.csv")

# Replace "Windy" with "WDY" in the "Weather" column
df["Weather"] = df["Weather"].replace("Windy", "WDY")

# Save the modified file
updated_file_path = "updated_amazon_delivery.csv"
df.to_csv(updated_file_path, index=False)

print("Replacement completed successfully.")
# Out:
# Replacement completed successfully.

# %%
df = pd.read_csv("amazon_delivery.csv")

# Replace values in the "Area" column
df["Area"] = df["Area"].replace({"Urban": 1, "Metropolitian": 0})

# Save the updated file
df.to_csv("amazon_delivery_updated.csv", index=False)

print("Replacement completed and saved as amazon_delivery_updated.csv")
# Out:
# Replacement completed and saved as amazon_delivery_updated.csv

# %%
df = pd.read_csv("amazon_delivery.csv")

df["Weather"] = df["Weather"].replace("Windy", "WDY")

# Save the modified file
updated_file_path = "amazon_delivery_updated.csv"
df.to_csv(updated_file_path, index=False)

# Display the first few rows to verify changes
df.head()
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Convert 'Agent_Age' to numeric, coercing errors to NaN
df['Agent_Age'] = pd.to_numeric(df['Agent_Age'], errors='coerce')

# Calculate the mean, ignoring NaN values
mean_age = df['Agent_Age'].mean()

# Fill NA values with the calculated mean
df['Agent_Age'].fillna(mean_age, inplace=True)

# Save the cleaned file (optional)
df.to_csv("amazon_delivery_cleaned.csv", index=False)

# Display the first few rows to verify
print(df.head())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6476\1490366224.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Agent_Age'].fillna(mean_age, inplace=True)
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Replace all occurrences of 100 with 50
df.replace(100, 50, inplace=True)

# Display the first few rows to verify the change
print(df.head())

# Save the modified DataFrame back to a CSV file (optional)
df.to_csv("amazon_delivery_modified.csv", index=False)
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
                                               # INDEX : INDEXING AND INDEXING RESETTING

# %%
df = pd.read_csv("amazon_delivery.csv")

# Set "Vehicle" as the index
df.set_index("Vehicle", inplace=True)

# Display the first few rows
print(df.head())
# Out:
#                   Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# Vehicle
# motorcycle   ialx566343618         37           4.9       22.745049
# scooter      akqg208421122         34           4.5       12.913041
# motorcycle   njpu434582536         23           4.4       12.914264
# motorcycle   rjto796129700         38           4.7       11.003669
# scooter      zguw716275638         32           4.6       12.972793
#
#              Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date  \
# Vehicle
# motorcycle         75.892471      22.765049       75.912471  2022-03-19
# scooter            77.683237      13.043041       77.813237  2022-03-25
# motorcycle         77.678400      12.924264       77.688400  2022-03-19
# motorcycle         76.976494      11.053669       77.026494  2022-04-05
# scooter            80.249982      13.012793       80.289982  2022-03-26
#
#             Order_Time Pickup_Time     Weather  Traffic            Area  \
# Vehicle
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Set "Order_ID" as the index
df.set_index("Order_ID", inplace=True)

# Reset the index
df.reset_index(inplace=True)

# Display the first few rows
print(df.head())
# Out:
#         Order_ID  Agent_Age  Agent_Rating  Store_Latitude  Store_Longitude  \
# 0  ialx566343618         37           4.9       22.745049        75.892471
# 1  akqg208421122         34           4.5       12.913041        77.683237
# 2  njpu434582536         23           4.4       12.914264        77.678400
# 3  rjto796129700         38           4.7       11.003669        76.976494
# 4  zguw716275638         32           4.6       12.972793        80.249982
#
#    Drop_Latitude  Drop_Longitude  Order_Date Order_Time Pickup_Time  \
# 0      22.765049       75.912471  2022-03-19   11:30:00    11:45:00
# 1      13.043041       77.813237  2022-03-25   19:45:00    19:50:00
# 2      12.924264       77.688400  2022-03-19   08:30:00    08:45:00
# 3      11.053669       77.026494  2022-04-05   18:00:00    18:10:00
# 4      13.012793       80.289982  2022-03-26   13:30:00    13:45:00
#
#       Weather  Traffic      Vehicle            Area  Delivery_Time  \
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Display basic information and the first few rows
df.info(), df.head()
df_cleaned = df.dropna(subset=["Weather", "Agent_Age"])

# Set multi-level index using Weather and Agent_Age
df_indexed = df_cleaned.set_index(["Weather", "Agent_Age"])

# Display the first few rows of the indexed dataframe
df_indexed.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43739 entries, 0 to 43738
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         43739 non-null  object
#  1   Agent_Age        43739 non-null  int64
#  2   Agent_Rating     43685 non-null  float64
#  3   Store_Latitude   43739 non-null  float64
#  4   Store_Longitude  43739 non-null  float64
#  5   Drop_Latitude    43739 non-null  float64
#  6   Drop_Longitude   43739 non-null  float64
#  7   Order_Date       43739 non-null  object
#  8   Order_Time       43739 non-null  object
#  9   Pickup_Time      43739 non-null  object
#  10  Weather          43648 non-null  object
#  11  Traffic          43739 non-null  object
#  12  Vehicle          43739 non-null  object
#  13  Area             43739 non-null  object
#  14  Delivery_Time    43739 non-null  int64
#  15  Category         43739 non-null  object
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Set "Weather" as the index
df.set_index("Weather", inplace=True)

# Access a specific row using a weather condition, e.g., "sunny"
specific_row = df.loc["sunny"]

# Display the result
print(specific_row)
# Out:
#               Order_ID  Agent_Age  Agent_Rating  Store_Latitude  \
# Weather
# sunny    ialx566343618         37           4.9       22.745049
# sunny    rjto796129700         38           4.7       11.003669
# sunny    owvs520891091         29           4.5       13.005801
# sunny    ezif478391605         33           4.9       18.551440
# sunny    czjt755903822         35           5.0       17.451976
# ...                ...        ...           ...             ...
# sunny    twav822039720         35           4.9       26.846156
# sunny    msyf291805076         36           4.8       11.008638
# sunny    myqj496556814         32           4.9       12.334022
# sunny    txib370478343         21           4.8       19.103249
# sunny    llbw528617620         36           4.8       12.310972
#
#          Store_Longitude  Drop_Latitude  Drop_Longitude  Order_Date  \
# Weather
# sunny          75.892471      22.765049       75.912471  2022-03-19
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Check if 'Order_ID' is unique
is_unique = df["Order_ID"].is_unique

# Get index type
index_type = df.index.dtype

print("Is 'Order_ID' unique?:", is_unique)
print("Index type:", index_type)
# Out:
# Is 'Order_ID' unique?: True
# Index type: int64

# %%
                                                    # GROUPBY  : GROUPING DATA

# %%
# Load the dataset
df = pd.read_csv("amazon_delivery.csv")

# Ensure column names are correctly formatted (trim spaces, standardize case)
df.columns = df.columns.str.strip()

# Check if required columns exist to avoid KeyErrors
required_columns = {"Weather", "Area", "Agent_Age"}
if not required_columns.issubset(df.columns):
    raise KeyError(f"Missing required columns: {required_columns - set(df.columns)}")

# Convert 'Agent_Age' to numeric (handle errors to avoid issues)
df["Agent_Age"] = pd.to_numeric(df["Agent_Age"], errors="coerce")

# Group by 'Weather' and 'Area', then calculate the average 'Agent_Age'
result = df.groupby(["Weather", "Area"])["Agent_Age"].mean().reset_index()

# Display the result
print(result)

# Save the output to a new CSV file if needed
result.to_csv("average_agent_age_by_weather_and_area.csv", index=False)
# Out:
#        Weather            Area  Agent_Age
# 0       cloudy  Metropolitian   29.724002
# 1       cloudy           Other  29.447853
# 2       cloudy     Semi-Urban   32.951220
# 3       cloudy          Urban   29.098864
# 4          fog  Metropolitian   29.496945
# 5          fog           Other  28.906832
# 6          fog     Semi-Urban   32.838710
# 7          fog          Urban   29.177090
# 8   sandstorms  Metropolitian   29.936143
# 9   sandstorms           Other  28.168269
# 10  sandstorms     Semi-Urban   34.000000
# 11  sandstorms          Urban   28.342735
# 12      stormy  Metropolitian   29.866884
# 13      stormy           Other  29.094241
# 14      stormy     Semi-Urban   34.000000
# 15      stormy          Urban   28.810794
# 16       sunny  Metropolitian   29.845504
# 17       sunny           Other  29.009302
# 18       sunny     Semi-Urban   25.631579
# 19       sunny          Urban   29.162840
# 20       windy  Metropolitian   29.799669
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by Agent_Age and count occurrences of each Category
category_counts = df.groupby("Agent_Age")["Category"].value_counts().unstack(fill_value=0)

# Display the first few rows of the result
category_counts.head()
# Out:
# Category   Apparel  Books  Clothing  Cosmetics  Electronics  Grocery  Home  \
# Agent_Age
# 15               1      3         3          2            3        0     3
# 20             114    145       158         98          149      130   129
# 21             120    117       124        133          145      119   147
# 22             150    130       126        117          144      147   140
# 23             146    151       147        121          132      116   125
#
# Category   Jewelry  Kitchen  Outdoors  Pet Supplies  Shoes  Skincare  Snacks  \
# Agent_Age
# 15               4        3         3             2      1         2       3
# 20             149      142       127           131    126       135     122
# 21             146      137       144           147    126       140     143
# 22             138      111       139           131    144       136     152
# 23             115      112       137           134    113       135     120
#
# Category   Sports  Toys
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by Agent_Age and sum the Agent_Rating
age_grouped_ratings = df.groupby("Agent_Age")["Agent_Rating"].sum().reset_index()

# Display the result
print(age_grouped_ratings)
# Out:
#     Agent_Age  Agent_Rating
# 0          15          38.0
# 1          20        9965.3
# 2          21       10078.0
# 3          22       10249.0
# 4          23        9764.9
# 5          24       10317.4
# 6          25       10148.4
# 7          26       10086.6
# 8          27       10046.6
# 9          28       10196.4
# 10         29       10230.7
# 11         30       10213.5
# 12         31        9716.0
# 13         32       10085.3
# 14         33       10038.9
# 15         34        9944.0
# 16         35       10370.9
# 17         36       10376.9
# 18         37       10237.9
# 19         38       10181.6
# 20         39        9822.4
# 21         50         318.0

# %%
df = pd.read_csv("amazon_delivery.csv")  # Update with the correct file path

# Display the actual column names to identify inconsistencies
print("Column Names:", df.columns)

# Strip any whitespace from column names
df.columns = df.columns.str.strip()

# Check if a different case or spelling is used
print("Updated Column Names:", df.columns)

# Ensure the column exists and rename if needed
expected_column = "Agent_id"  # Change based on actual column name
if expected_column not in df.columns:
    corrected_name = [col for col in df.columns if "agent" in col.lower()]
    if corrected_name:
        df.rename(columns={corrected_name[0]: expected_column}, inplace=True)

# Now perform the groupby operation
result = df.groupby("Vehicle")[expected_column].nunique()

# Print the result
print(result)
# Out:
# Column Names: Index(['Order_ID', 'Agent_Age', 'Agent_Rating', 'Store_Latitude',
#        'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 'Order_Date',
#        'Order_Time', 'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area',
#        'Delivery_Time', 'Category'],
#       dtype='object')
# Updated Column Names: Index(['Order_ID', 'Agent_Age', 'Agent_Rating', 'Store_Latitude',
#        'Store_Longitude', 'Drop_Latitude', 'Drop_Longitude', 'Order_Date',
#        'Order_Time', 'Pickup_Time', 'Weather', 'Traffic', 'Vehicle', 'Area',
#        'Delivery_Time', 'Category'],
#       dtype='object')
# Vehicle
# bicycle         2
# motorcycle     22
# scooter        22
# van            22
# Name: Agent_id, dtype: int64

# %%
                                                # GROUPBY : GROUPING DATA

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by Category and count unique Vehicle types
result = df.groupby("Category")["Vehicle"].nunique().reset_index()

# Display result
print(result)
# Out:
#         Category  Vehicle
# 0        Apparel        3
# 1          Books        4
# 2       Clothing        4
# 3      Cosmetics        3
# 4    Electronics        4
# 5        Grocery        3
# 6           Home        4
# 7        Jewelry        4
# 8        Kitchen        3
# 9       Outdoors        3
# 10  Pet Supplies        3
# 11         Shoes        3
# 12      Skincare        4
# 13        Snacks        4
# 14        Sports        4
# 15          Toys        4

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by Agent_Age and count occurrences of each Area
area_counts = df.groupby("Agent_Age")["Area"].value_counts().unstack(fill_value=0)

# Display the result
print(area_counts)
# Out:
# Area       Metropolitian   Other  Semi-Urban   Urban
# Agent_Age
# 15                     27      0            0      11
# 20                   1545     63            3     525
# 21                   1531     62            2     558
# 22                   1585     54            3     554
# 23                   1507     53            2     525
# 24                   1552     82            3     573
# 25                   1528     74            3     569
# 26                   1550     70            4     535
# 27                   1515     70            4     561
# 28                   1560     67            7     545
# 29                   1551     70            1     569
# 30                   1774     39           12     401
# 31                   1645     51           21     403
# 32                   1700     50           12     440
# 33                   1730     56            3     398
# 34                   1699     39            8     420
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Display the first few rows to understand its structure
df.head() 

# Group by Weather and count occurrences of each Category
category_counts_by_weather = df.groupby(["Weather", "Category"]).size().reset_index(name="Total_Sales")

# Display the result
category_counts_by_weather.head()
# Out:
#   Weather     Category  Total_Sales
# 0  cloudy      Apparel          440
# 1  cloudy        Books          479
# 2  cloudy     Clothing          435
# 3  cloudy    Cosmetics          456
# 4  cloudy  Electronics          453

# %%
f = pd.read_csv("amazon_delivery.csv")

# Group by Agent_Age and sum the Agent_Age values
result = df.groupby("Agent_Age")["Agent_Rating"].sum().reset_index()

# Display the result
print(result)
# Out:
#     Agent_Age  Agent_Rating
# 0          15          38.0
# 1          20        9965.3
# 2          21       10078.0
# 3          22       10249.0
# 4          23        9764.9
# 5          24       10317.4
# 6          25       10148.4
# 7          26       10086.6
# 8          27       10046.6
# 9          28       10196.4
# 10         29       10230.7
# 11         30       10213.5
# 12         31        9716.0
# 13         32       10085.3
# 14         33       10038.9
# 15         34        9944.0
# 16         35       10370.9
# 17         36       10376.9
# 18         37       10237.9
# 19         38       10181.6
# 20         39        9822.4
# 21         50         318.0

# %%
df = pd.read_csv("amazon_delivery.csv")

# Display the first few rows to understand its structure
df.head()

category_vehicle_counts = df.groupby("Category")["Vehicle"].nunique()

# Display the result
category_vehicle_counts
# Out:
# Category
# Apparel         3
# Books           4
# Clothing        4
# Cosmetics       3
# Electronics     4
# Grocery         3
# Home            4
# Jewelry         4
# Kitchen         3
# Outdoors        3
# Pet Supplies    3
# Shoes           3
# Skincare        4
# Snacks          4
# Sports          4
# Toys            4
# Name: Vehicle, dtype: int64

# %%
                            #AGGREATATION: PERFORMING MULTIPLE AGGREATATION

# %%
df = pd.read_csv("amazon_delivery.csv")

# Display the first few rows to inspect the structure
df.head()

age_stats = df.groupby('Category')['Agent_Age'].agg(['mean', 'median'])

# Display the results
age_stats
# Out:
#                    mean  median
# Category
# Apparel       29.482392    29.0
# Books         29.646955    30.0
# Clothing      29.445069    30.0
# Cosmetics     29.828166    30.0
# Electronics   29.560548    30.0
# Grocery       29.594203    29.0
# Home          29.514711    30.0
# Jewelry       29.508208    30.0
# Kitchen       29.689113    30.0
# Outdoors      29.406989    29.0
# Pet Supplies  29.547212    30.0
# Shoes         29.691673    30.0
# Skincare      29.586580    30.0
# Snacks        29.683032    30.0
# Sports        29.508275    30.0
# Toys          29.389069    29.0

# %%
df = pd.read_csv("amazon_delivery.csv")

# Display the first few rows to understand its structure
df.head()

# Perform aggregations on Agent_Rating grouped by Category
aggregated_df = df.groupby("Category")["Agent_Rating"].agg(["sum", "mean", "count"])

# Display the aggregated result
aggregated_df
# Out:
#                   sum      mean  count
# Category
# Apparel       12606.2  4.631227   2722
# Books         13076.9  4.637199   2820
# Clothing      12345.6  4.637716   2662
# Cosmetics     12378.3  4.630864   2673
# Electronics   13187.8  4.632174   2847
# Grocery       12462.3  4.632825   2690
# Home          12413.6  4.626761   2683
# Jewelry       12950.8  4.626938   2799
# Kitchen       12359.1  4.630611   2669
# Outdoors      12746.0  4.643352   2745
# Pet Supplies  12450.7  4.637132   2685
# Shoes         12364.3  4.648233   2660
# Skincare      12844.0  4.636823   2770
# Snacks        12793.2  4.626835   2765
# Sports        12563.5  4.625736   2716
# Toys          12884.4  4.636344   2779

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by 'Category' and compute min and max for numerical columns
grouped_df = df.groupby("Category").agg({
    "Agent_Age": ["min", "max"],
    "Agent_Rating": ["min", "max"],
    "Delivery_Time": ["min", "max"]
}).reset_index()

# Display the result
print(grouped_df)
# Out:
#         Category Agent_Age     Agent_Rating      Delivery_Time
#                        min max          min  max           min  max
# 0        Apparel        15  50          1.0  6.0            50  270
# 1          Books        15  50          1.0  6.0            50  270
# 2       Clothing        15  50          1.0  6.0            50  270
# 3      Cosmetics        15  50          1.0  6.0            50  270
# 4    Electronics        15  50          1.0  6.0            50  270
# 5        Grocery        20  50          2.5  6.0            10   54
# 6           Home        15  50          1.0  6.0            50  270
# 7        Jewelry        15  50          1.0  6.0            50  270
# 8        Kitchen        15  50          1.0  6.0            50  270
# 9       Outdoors        15  50          1.0  6.0            50  270
# 10  Pet Supplies        15  50          1.0  6.0            50  270
# 11         Shoes        15  50          1.0  6.0            50  270
# ...

# %%
df = pd.read_csv("amazon_delivery.csv")

# Define a function to calculate the range (max - min)
def age_range(series):
    return series.max() - series.min()

# Group by Category and Area, then apply the custom aggregation
result = df.groupby(["Category", "Area"])['Agent_Age'].agg(Age_Range=age_range).reset_index()

# Display result
print(result)
# Out:
#    Category            Area  Age_Range
# 0   Apparel  Metropolitian          35
# 1   Apparel           Other         19
# 2   Apparel     Semi-Urban          14
# 3   Apparel          Urban          30
# 4     Books  Metropolitian          35
# ..      ...             ...        ...
# 59   Sports          Urban          35
# 60     Toys  Metropolitian          35
# 61     Toys           Other         19
# 62     Toys     Semi-Urban          15
# 63     Toys          Urban          30
#
# [64 rows x 3 columns]

# %%
df = pd.read_csv("amazon_delivery.csv")

# Group by 'Area' and calculate standard deviation and variance of 'Delivery_Time'
result = df.groupby("Area")["Delivery_Time"].agg(["std", "var"])

# Display the result
print(result)
# Out:
#                       std          var
# Area
# Metropolitian   51.578971  2660.390257
# Other           45.943400  2110.796037
# Semi-Urban      47.033282  2212.129662
# Urban           48.185011  2321.795276
